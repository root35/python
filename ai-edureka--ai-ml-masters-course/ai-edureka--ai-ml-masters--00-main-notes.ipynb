# %%
import ipywidgets as widgets

# %%
widgets.Checkbox(value=False, description='01 Python Statistics for Data Science', disabled=False)
# Out:
# Checkbox(value=False, description='01 Python Statistics for Data Science')

# %% [markdown]
# # AI and Machine Learning Masters Courses

# %% [markdown]
# <hr style="border:2px solid black">
#
# #  🔵 01 – Python Statistics for Data Science (Self-Paced)
#
# <br>
#
# ### Understanding the data
#
# ### Probability and its uses
#
# ### Statistical Inference
#
# ### Testing the data
#
# ### Data Clustering
#
# ### Regression Modelling
#
# ### ℹ️ Introductory videos for PGP
#
# * Machine Learning
# * Graphical Modelling
# * Reinforcement Learning
# * Natural Language Processing
# * What is Deep Learning?
# * Deep Learning tutorial

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 02 – Python Certification
#
# <br>
#
# ### 🛠️ Installation guides
#
# ### Introduction to Python
#
# ### Sequences and file operations
#
# ### Functions and Object-Oriented Programming
#
# ### Working with modules and handling exceptions
#
# ### Array manipulation using NumPy
#
# ### Data manipulation using Pandas
#
# ### Data visualization using Matplotlib and Seaborn
#
# ### GUI programming
#
# ### 🔵 Developing Web Maps and representing information using Plots (self-paced)
#
# ### 🔵 Web scraping and Computer Vision using OpenCV (self-paced)
#
# ### 🔵 Database integration with Python (self-paced)
#
# ### 💯 Practice project
#
# ### ✅ Final quiz
#
# ### 💯 Certification project
#
# ### 📚 Reference materials
#
# ### 💼 Interview preparation
#
# ### 📗 Additional resources

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 03 – Data Science with Python
#
# <br>
#
# #### ℹ️ Pre-requisites
#
# *Content of module "01 Python Statistics for Data Science"*
#
# * Understanding data
# * Probabilities
# * Statistical Inference
# * Testing data
# * Data Clustering
# * Regression Modelling
#
# ### 🛠️ Guide to access Cloud Lab
#
# ### Introduction to Data Science and Machine Learning using Python
#
# ### Sequences and file operations
#
# ### Deep Dive – Functions, OOPs, Modules, Errors and Exceptions
#
# ### Introduction to NumPy, Pandas and Matplotlib
#
# ### Data Manipulation
#
# ### Introduction to Machine Learning with Python
#
# ### Supervised Learning – I
#
# ### Dimensionality Reduction
#
# ### Supervised Learning – II
#
# ### Unsupervised Learning
#
# ### Association Rules Mining and Recommendation Systems
#
# ### Reinforcement Learning
#
# ### Time Series Analysis
#
# ### Model Selection and Boosting
#
# ### 🔵 Statistical Foundations (self-paced)
#
# ### 🔵 Database Integration with Python (self-paced)
#
# ### 🔵 Data Connection and Visualization in Tableau (self-paced)
#
# ### 🔵 Advanced visualizations (self-paced)
#
# ### 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 04 – Artificial Intelligence
#
# <br>
#
# ### Introduction to Text Mining and NLP
#
# ### Extracting, Cleaning and Pro-processing text
#
# ### Analyzing Sentence Structure
#
# ### Text Classification – I
#
# ### Introduction to Deep Learning
#
# ### Getting started with TensorFlow 2.0
#
# ### Convolutional Neural Network
#
# ### Regional CNN
#
# ### Boltzmann Machine and Autoencoder
#
# ### Generative Adversarial Network (GAN)
#
# ### 🔵 Emotion and Gender Detection (self-paced)
#
# ### 🔵 Introduction to RNN and GRU (self-paced)
#
# ### 🔵 LSTM (self-paced)
#
# ### 🔵 Auto image captioning using CNN LSTM (self-paced)
#
# ### 🔵 Developing and Criminal Identification and Detection Application Using OpenCV (self-paced)
#
# ### 🔵 TensorFlow for Deployment (self-paced)
#
# ### 🔵 Text Classification – II (self-paced)
#
# ### 💯 In-class project (self-paced)

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 05 – ChatGPT-4 Complete Course Beginners to Advanced
#
# <br>
#
# #### ℹ️ Pre-requisite 1 – Python
#
# #### ℹ️ Pre-requisite 2 –  Machine Learning
#
# #### ℹ️ Pre-requisite 3 –  NLP
#
# #### ℹ️ Pre-requisite 4 –  HTML, CSS, Js
#
# ### Introduction to OpenAI and ChatGPT
#
# ### Business use cases of ChatGPT
#
# ### Developping web application using ChatGPT
#
# ### Deploying and Integrating ChatGPT in Business applications
#
# ### GPT Models, pre-processing and fine-tuning ChatGPT
#
# ### Working with OpenAI and ChatGPT API
#
# ### 🔵 Working with GPT-3 (self-paced)
#
# ### 🔵 Building and deploying GPT-3 powered application (self-paced)
#
# ### 🔵 Building real-world applications with OpenAI API and ChatGPT (self-paced)
#
# ### 🔵 ChatGPT – Best practices, limitations and avenues for future development (self-paced)
#
# ### ✅ Final quiz
#
# ### 💯 Certification project
#
# * Project 1 – Developping an OpenAI clone
# * Project 2 – Digital Marketing with ChatGPT

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 06 – PySpark
#
# <br>
#
# ### Introduction to Big Data Hadoop and Spark
#
# ### Introduction to Python for Apache Spark
#
# ### Functions, OOPs, Modules in Python
#
# ### Deep Dive into Apache Spark Framework
#
# ### Playing with Spark RDDs
#
# ### DataFrames and Spark SQL
#
# ### Machine Learning using Spark MLlib
#
# ### Deep Dive into Spark MLlib
#
# ### Understanding Apache Kafka and Apache Flume
#
# ### Apache Spark Streaming – Processing Multiple Batches
#
# ### Apache Spark Streaming – Data Sources
#
# ### 💯 In-class project
#
# ### 🔵 Spark GraphX
#
# ### 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 🔵 07 – Capstone Project (Self-Paced)
#
# <br>

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 🔵 08 – Python Scripting (Self-Paced)
#
# <br>
#
# ### 🛠️ Installation guide
#
# ### Introduction to Python
#
# ### Sequences and File Operations
#
# ### Deep Dive – Functions, OOPs, Modules, Errors and Exceptions
#
# ### Introduction to NumPy and Pandas
#
# ### Data Visualization
#
# ### 💯 Certification Project

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 🔵 09 – Reinforcement Learning (Self-Paced)
#
# <br>
#
# #### ℹ️ Pre-requisite 1 – Python
#
# #### ℹ️ Pre-requisite 2 – Machine Learning
#
# #### ℹ️ Pre-requisite 2 – Deep Learning
#
# ### Introduction to Reinforcement Learning
#
# ### Bandit Algorithms and Markov Decision Process
#
# ### Dynamic Programming and Temporal Difference Learning methods
#
# ### Deep Q Learning
#
# ### 💯 In-class project
#
# ### 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 🔵 10 – Graphical Models (Self-Paced)
#
# <br>
#
# #### ℹ️ Pre-requisite 1 – Python
#
# #### ℹ️ Pre-requisite 2 – Machine Learning
#
# ### Introduction to Graphical Models
#
# ### Bayesian Network
#
# ### Markov's Networks
#
# ### Inference
#
# ### Model Learning
#
# ### 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# # 🔵 11 – Sequence Learning (Self-Paced)
#
# <br>
#
# ### Introduction to Sequence Learning
#
# ### RNN vs LSTM with Google Stock Price
#
# ### Sentiment Analysis on Zomato Reviews using LSTMs
#
# ### Introduction to the Transformer Model
#
# ### BERT and GPT-2 using Transformers
#
# ### Machine Translation using MT5
#
# ### Building and Question-Answer Prediction Model using BERT
#
# ### ✅ Final Quiz
#
# ### 💯 Certification project
