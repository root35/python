# %% [markdown]
#  <H1 style="color: black; font-size: 55px;">Deep Learning</H1>

# %% [markdown]
# <a name="01"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">1. Understanding Neural Networks with TensorFlow</H1>

# %% [markdown]
# <img src="images/065.png" width="650">

# %% [markdown]
# <a name="01-01"></a>
# <H2 style="color: MediumBlue; font-size: 21px; background-color: #F0F8FF; padding: 15px 20px;">Tensors</H2>
#
# <img src="images/066.png" width="650">
# <img src="images/067.png" width="650">
# <img src="images/068.png" width="650">
# <img src="images/069.png" width="650">
# <img src="images/070.png" width="650">
#
# * `X`: input features
# * `W`: their weights
# * `Matmul`*: matrix multiplication between `X` and `W`
# * `B` add the bias term to the result of matmul
# * `Relu`: then apply the activation function

# %% [markdown]
# <H2 style="color: MediumBlue; font-size: 21px; background-color: #F0F8FF; padding: 15px 20px;">How it works in TensorFlow</H2>
#
# * We define the entire flow
# * Then we only run the last component: Relu
# * This last component will go back and calculated the preceding components in the backend
#
# <img src="images/070.png" width="650">
# <img src="images/071.png" width="650">

# %%
# !python --version
# !pip install --upgrade tensorflow==2.7.3
# Out:
# Python 3.7.6
# Collecting tensorflow==2.7.3
#   Using cached tensorflow-2.7.3-cp37-cp37m-macosx_10_11_x86_64.whl (213.0 MB)
# Requirement already satisfied: numpy>=1.14.5 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (1.19.5)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (0.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (1.6.3)
# Collecting libclang>=9.0.1 (from tensorflow==2.7.3)
#   Using cached libclang-16.0.0-py2.py3-none-macosx_10_9_x86_64.whl (26.7 MB)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (1.12)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (3.13.0)
# Requirement already satisfied: six>=1.12.0 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (3.10.0.2)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (0.37.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (1.12.1)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (0.4.0)
# Requirement already satisfied: tensorboard~=2.6 in /Users/macbook/anaconda3/lib/python3.7/site-packages (from tensorflow==2.7.3) (2.6.0)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0 (from tensorflow==2.7.3)
#   Using cached tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Collecting keras<2.8,>=2.7.0rc0 (from tensorflow==2.7.3)
#   Using cached keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# INFO: pip is looking at multiple versions of tensorflow to determine which version is compatible with other requirements. This could take a while.
# ERROR: Ignored the following versions that require a different python version: 2.12.0 Requires-Python >=3.8; 2.12.0rc0 Requires-Python >=3.8; 2.12.0rc1 Requires-Python >=3.8; 2.13.1rc0 Requires-Python >=3.8
# ERROR: Could not find a version that satisfies the requirement tensorflow-io-gcs-filesystem>=0.21.0 (from tensorflow) (from versions: none)
# ERROR: No matching distribution found for tensorflow-io-gcs-filesystem>=0.21.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.5

# %%
@tf.function
def f():
    constant = tf.constant('hello')
    print(constant)
    tf.print(constant)
f()
# Out:
# Tensor("Const:0", shape=(), dtype=string)
# hello

# %% [markdown]
# <a name="01"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">2. Deep Dive into Neural Networks with TensorFlow</H1>

# %% [markdown]
# <a name="01"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">3. Master Deep Networks</H1>

# %% [markdown]
# <a name="01"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">4. Convolutional Neural Networks (CNN)</H1>
