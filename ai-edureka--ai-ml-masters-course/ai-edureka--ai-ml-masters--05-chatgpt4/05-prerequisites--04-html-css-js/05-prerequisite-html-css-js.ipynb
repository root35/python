# %% [markdown]
# * [1. HTML](#01)
# * [2. CSS](#02)
# * [3. JavaScript](#03)
# * [4. NodeJS](#04)
# * [5. React.JS](#05)
# * [6. MongoDB](#06)

# %% [markdown]
# <a name="01"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">1. HTML</H1>

# %% [markdown]
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">2. CSS</H1>
#
# <img src="css_syntax.png" width="650">
#
# [CSS Selectors Reference – W3Schools](https://www.w3schools.com/cssref/css_selectors.php)
# <img src="css_selectors.png" width="650">
# <img src="css_selectors2.png" width="650">
#
# <img src="css_box_model.png" width="650">
#
# <img src="css_units.png" width="650">

# %% [markdown]
# <a name="03"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">3. JavaScript</H1>

# %% [markdown]
# <a name="04"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">4. NodeJS</H1>

# %% [markdown]
# <a name="05"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">5. React.JS</H1>

# %% [markdown]
# <a name="06"></a>
# <H1 style="color: MediumBlue; font-size: 34px; background-color: #E6E6FA; padding: 30px 20px;">6. MongoDB</H1>
