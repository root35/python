# %%
import ipywidgets as widgets

# %%
widgets.Checkbox(value=False, description='01 Python Statistics for Data Science', disabled=False)
# Out:
# Checkbox(value=False, description='01 Python Statistics for Data Science')

# %% [markdown]
# <H1 style="color: black; font-size: 55px;">AI and Machine Learning Masters</H1>

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">01 • Python Statistics for Data Science (Self-Paced)</H1>
#
# <br>
#
# 1. Understanding the data
# 2. Probability and its uses
# 3. Statistical Inference
# 4. Testing the data
# 5. Data Clustering
# 6. Regression Modelling
# 7. ℹ️ Introductory videos for PGP
#     * Machine Learning
#     * Graphical Modelling
#     * Reinforcement Learning
#     * Natural Language Processing
#     * What is Deep Learning?
#     * Deep Learning tutorial

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">02 • Python Certification</H1>
#
# <br>
#
# 0. 🛠️ Installation guides
# 1. Introduction to Python
# 2. Sequences and file operations
# 3. Functions and Object-Oriented Programming
# 4. Working with modules and handling exceptions
# 5. Array manipulation using NumPy
# 6. Data manipulation using Pandas
# 7. Data visualization using Matplotlib and Seaborn
# 8. GUI programming
# 9. 🔵 Developing Web Maps and representing information using Plots (self-paced)
# 10. 🔵 Web scraping and Computer Vision using OpenCV (self-paced)
# 11. 🔵 Database integration with Python (self-paced)
# 12. 💯 Practice project
# 13. ✅ Final quiz
# 14. 💯 Certification project
# 15. 📚 Reference materials
# 16. 💼 Interview preparation
# 17. 📗 Additional resources

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">03 • Data Science with Python</H1>
#
# <br>
#
# 1. ℹ️ Pre-requisites
#
# *Content of module "01 Python Statistics for Data Science":*
# • Understanding data • Probabilities • Statistical Inference • Testing data • Data Clustering • Regression Modelling
#
# 2. 🛠️ Guide to access Cloud Lab
# 3. Introduction to Data Science and Machine Learning using Python
# 4. Sequences and file operations
# 5. Deep Dive – Functions, OOPs, Modules, Errors and Exceptions
# 6. Introduction to NumPy, Pandas and Matplotlib
# 7. Data Manipulation
# 8. Introduction to Machine Learning with Python
# 9. Supervised Learning – I
# 10. Dimensionality Reduction
# 11. Supervised Learning – II
# 12. Unsupervised Learning
# 13. Association Rules Mining and Recommendation Systems
# 14. Reinforcement Learning
# 15. Time Series Analysis
# 16. Model Selection and Boosting
# 17. 🔵 Statistical Foundations (self-paced)
# 18. 🔵 Database Integration with Python (self-paced)
# 19. 🔵 Data Connection and Visualization in Tableau (self-paced)
# 20. 🔵 Advanced visualizations (self-paced)
# 21. 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">04 • Artificial Intelligence</H1>
#
# <br>
#
# 1. Introduction to Text Mining and NLP
# 2. Extracting, Cleaning and Pro-processing text
# 3. Analyzing Sentence Structure
# 4. Text Classification – I
# 5. Introduction to Deep Learning
# 6. Getting started with TensorFlow 2.0
# 7. Convolutional Neural Network
# 8. Regional CNN
# 9. Boltzmann Machine and Autoencoder
# 10. Generative Adversarial Network (GAN)
# 11. 🔵 Emotion and Gender Detection (self-paced)
# 12. 🔵 Introduction to RNN and GRU (self-paced)
# 13. 🔵 LSTM (self-paced)
# 14. 🔵 Auto image captioning using CNN LSTM (self-paced)
# 15. 🔵 Developing and Criminal Identification and Detection Application Using OpenCV (self-paced)
# 16. 🔵 TensorFlow for Deployment (self-paced)
# 17. 🔵 Text Classification – II (self-paced)
# 18. 💯 In-class project (self-paced)

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">05 • ChatGPT-4 Complete Course Beginners to Advanced</H1>
#
# <br>
#
# 1. Pre-requisites
#     * ℹ️ Python <span style="color:red; font-weight:normal;">0/3</span>
#     * ℹ️ Machine Learning <span style="color:red; font-weight:normal;">0/2</span>
#     * ℹ️ NLP <span style="color:red; font-weight:normal;">2/3</span>
#     * ℹ️ HTML, CSS, JS <span style="color:red; font-weight:normal;">2/6</span>
#
#
# 2. ~~Introduction to OpenAI and ChatGPT~~
# 3. ~~Business use cases of ChatGPT~~
# 4. ~~Developping web application using ChatGPT~~
# 5. Deploying and Integrating ChatGPT in Business applications
# 6. ~~GPT Models, pre-processing and fine-tuning ChatGPT~~
# 7. Working with OpenAI and ChatGPT API
# 8. 🔵 Working with GPT-3 (self-paced)
# 9. 🔵 Building and deploying GPT-3 powered application (self-paced)
# 10. 🔵 Building real-world applications with OpenAI API and ChatGPT (self-paced)
# 11. 🔵 ChatGPT – Best practices, limitations and avenues for future development (self-paced)
# 12. ✅ Final quiz
# 13. 💯 Certification project
#     * Project 1 – Developping an OpenAI clone
#     * Project 2 – Digital Marketing with ChatGPT

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">06 • PySpark</H1>
#
# <br>
#
# 1. Introduction to Big Data Hadoop and Spark
# 2. Introduction to Python for Apache Spark
# 3. Functions, OOPs, Modules in Python
# 4. Deep Dive into Apache Spark Framework
# 5. Playing with Spark RDDs
# 6. DataFrames and Spark SQL
# 7. Machine Learning using Spark MLlib
# 8. Deep Dive into Spark MLlib
# 9. Understanding Apache Kafka and Apache Flume
# 10. Apache Spark Streaming – Processing Multiple Batches
# 11. Apache Spark Streaming – Data Sources
# 12. 💯 In-class project
# 13. 🔵 Spark GraphX
# 14. 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">07 • Capstone Project (Self-Paced)</H1>
#
# <br>

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">08 • Python Scripting (Self-Paced)</H1>
#
# <br>
#
# 1. 🛠️ Installation guide
# 2. Introduction to Python
# 3. Sequences and File Operations
# 4. Deep Dive – Functions, OOPs, Modules, Errors and Exceptions
# 5. Introduction to NumPy and Pandas
# 6. Data Visualization
# 7. 💯 Certification Project

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">09 • Reinforcement Learning (Self-Paced)</H1>
#
# <br>
#
# 1. Pre-requisites
#     * ℹ️ Python
#     * ℹ️ ~~Machine Learning~~ <span style="color:red; font-weight:normal;">4/4</span>
#     * ℹ️ ~~Deep Learning~~ <span style="color:red; font-weight:normal;">4/4</span>
#
#
# 2. Introduction to Reinforcement Learning
# 3. Bandit Algorithms and Markov Decision Process
# 4. Dynamic Programming and Temporal Difference Learning methods
# 5. Deep Q Learning
# 6. 💯 In-class project
# 7. 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">10 • Graphical Models (Self-Paced)</H1>
#
# <br>
#
# 1. Pre-requisites
#     * ℹ️ Python
#     * ℹ️ Machine Learning
#
#
# 2. Introduction to Graphical Models
# 3. Bayesian Network
# 4. Markov's Networks
# 5. Inference
# 6. Model Learning
# 7. 💯 Certification project

# %% [markdown]
# <hr style="border:2px solid black">
#
# <H1 style="color: black; font-size: 34px;">11 • Sequence Learning (Self-Paced)</H1>
#
# <br>
#
# 1. Introduction to Sequence Learning
# 2. RNN vs LSTM with Google Stock Price
# 3. Sentiment Analysis on Zomato Reviews using LSTMs
# 4. Introduction to the Transformer Model
# 5. BERT and GPT-2 using Transformers
# 6. Machine Translation using MT5
# 7. Building and Question-Answer Prediction Model using BERT
# 8. ✅ Final Quiz
# 9. 💯 Certification project
