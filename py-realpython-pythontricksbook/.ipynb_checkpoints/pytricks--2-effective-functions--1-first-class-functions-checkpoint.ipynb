# %% [markdown]
# # **PYTHON'S FUNCTIONS ARE FIRST-CLASS OBJECTS**
#
# * Can be assigned to variables
# * Can be stored in data structures
# * Can be passed as arguments to other functions
# * Can be returned as values from other functions
# Useful for understanding advanced features such as lambdas and decorators
# useful for learning functional programming techniques

# %%
def yell(text):
  return text.upper() + '!'

yell('hello')
# Out:
# 'HELLO!'

# %% [markdown]
# # **Functions are objects**
# * All data in a Python program is represented by objects or relations between objects:
# https://docs.python.org/3/reference/datamodel.html#objects-values-and-types

# %%
def yell(text):
  return text.upper() + '!'

bark = yell
bark('wook')  # create second name pointing to function object referenced by 'yell'
# Out:
# 'WOOK!'

# %% [markdown]
# * Function objects are separated from the variable pointing to them (their name)

# %%
def yell(text):
  return text.upper() + '!'

del yell          # delete function's original name
yell('hello')     # NameError: name 'yell' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8fd34ca1b959> in <module>
#       3
#       4 del yell          # delete the function's original name
# ----> 5 yell('hello')     # NameError: name 'yell' is not defined
#
# NameError: name 'yell' is not defined

# %%
def yell(text):
  return text.upper() + '!'

print(bark('hey'))
print('__name__: ', bark.__name__)          # 'yell' still original name
print('__qualname__: ', bark.__qualname__)  # qualified name (in python 3.3+)
# Out:
# HEY!
# __name__:  yell
# __qualname__:  yell

# %% [markdown]
# # **Functions can be stored in data structures**

# %%
funcs = [bark, str.lower, str.capitalize]

for f in funcs:
  print(f)
  print(f('hey there'))

funcs[0]('heyho')
# Out:
# <function yell at 0x10ca1eb90>
# HEY THERE!
# <method 'lower' of 'str' objects>
# hey there
# <method 'capitalize' of 'str' objects>
# Hey there
# 'HEYHO!'

# %% [markdown]
# # **Functions can be passed to other functions**
#
# * __Higher-order functions__:
#   * accepts functions as arguments
#   * a necessity for functional programming

# %%
def greet(func):
  greeting = func('Hi I am Xoxo')
  print(greeting)

def whisper(text):
  return text.lower() + '...'

def yell(text):
  return text.upper() + '!'

bark = yell
greet(bark)
greet(whisper)

# %% [markdown]
# * Classical example: the `map` function:
#   * takes an iterable and a function object,
#   * calls the function on each element in the iterable
#   * yielding the results as it goes along

# %%
list(map(bark, ['hello', 'hi', 'hey']))
# Out:
# HI I AM XOXO!
# hi i am xoxo...
# ['HELLO!', 'HI!', 'HEY!']

# %% [markdown]
# # **Functions can be nested**
# * PRO: functions can not only ***accept behaviors*** but also ***return behaviors***
# * __nested__ or __inner__ functions
# * An inner function is created at each call of the outer function

# %%
def speak(text):
  def whisper(t):
    return t.upper() + '...'
  return whisper(text)

speak('hello world')
whisper('Hey!')      # NameError: name 'whisper' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2d8cf6f14262> in <module>
#       5
#       6 speak('hello world')
# ----> 7 whisper('Hey!')  # NameError: name 'whisper' is not defined
#
# NameError: name 'whisper' is not defined

# %% [markdown]
# * But the inner function does not exist outside the outer function

# %%
speak.whisper       # AttributeError: 'function' object has no attribute 'whisper'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-45b62f573d6a> in <module>
# ----> 1 speak.whisper   # AttributeError: 'function' object has no attribute 'whisper'
#
# AttributeError: 'function' object has no attribute 'whisper'

# %%
def get_speak_func(volume):
  '''Accessing the innter function from outside the outer one'''

  def whisper(text):
    return text.lower() + '...'

  def yell(text):
    return text.upper() + '!'

  if volume > 0.5:
    return yell
  else:
    return whisper

print(get_speak_func(0.3))
print(get_speak_func(0.7))

speak_func = get_speak_func(0.3)
print(speak_func('Hello'))

speak_func = get_speak_func(0.7)
print(speak_func('Hello'))
# Out:
# <function get_speak_func.<locals>.whisper at 0x10ca46710>
# <function get_speak_func.<locals>.yell at 0x10ca46680>
# hello...
# HELLO!

# %% [markdown]
# # **Lexical closure: Functions can capture local state**
# * __Lexical closure__ (or just closure): they remember the value from their enclosing lexical scope even when the program flow is no longer in that scope
#
#
# * So python functions can:
#   * accept behaviors
#   * return behaviors
#   * pre-configure those behaviors

# %%
def get_speak_func(text, volume):
  '''Inner functions capturing their parent's parameter'''
  
  def whisper():
    return text.lower() + '...'

  def yell():
    return text.upper() + '!'

  if volume > 0.5:
    return yell
  else:
    return whisper

print(get_speak_func('Hello, world', 0.7)())
# Out:
# HELLO, WORLD!

# %%
def make_adder(n):
  '''Factory function creating and configuring adder functions'''
  def add(x):
    return x + n
  return add

plus_3 = make_adder(3)
plus_5 = make_adder(5)

print(plus_3(4))
print(plus_5(4))
# Out:
# 7
# 9

# %% [markdown]
# # **Objects can behave like functions**
# * All functions are objects but the reverse isn't true.
#
#
# * However, objects can be made __callable__ with the `__call__` dunder:
#   * can use the round parentheses function call syntax
#   * can pass in function arguments

# %%
class Adder:
  def __init__(self, n):
    self.n = n
  
  def __call__(self, x):
    return self.n + x

plus_3 = Adder(3)
print(plus_3(4))

print(callable(plus_3))
print(callable(greet))
print(callable('hello'))
# Out:
# 7
# True
# True
# False
