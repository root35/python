# %%
# !pip install openai
# Out:
# ...
#   Using cached openai-0.27.7-py3-none-any.whl (71 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.1/355.1 kB 7.2 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 4.9 MB/s eta 0:00:00
# ...
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# ...
#   Using cached urllib3-2.0.2-py3-none-any.whl (123 kB)
# ...
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.6 MB/s eta 0:00:00
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.9/797.9 kB 11.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 9.4 MB/s eta 0:00:00
# ...

# %%
import os
import openai
import tiktoken
_ = load_dotenv()
