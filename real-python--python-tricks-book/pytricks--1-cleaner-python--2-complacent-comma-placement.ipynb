# %% [markdown]
# # **COMPLACENT COMMA PLACEMENT**
# For list, dict and set constants

# %%
names = [
    'Sara',
    'Samy',
    'Lena',  # you never forget a comma when adding elements
]

# %%
names = [
    'Sara',
    'Samy',
    'Lena'   # missing comma! string literal concatenation turning into a liability!
    'Sherlock'
]
print(names)
# Out:
# ['Sara', 'Samy', 'LenaSherlock']

# %%
# String literal concatenation example
my_str = ('This is very long string constant '
          'spreading accross multiple lines. '
          'With no backlashes needed!')
print(my_str)
# Out:
# This is very long string constant spreading accross multiple lines. With no backlashes needed!
