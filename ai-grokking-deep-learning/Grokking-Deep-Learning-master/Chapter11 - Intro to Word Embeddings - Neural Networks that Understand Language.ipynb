# %% [markdown]
# # Download the IMDB Dataset

# %%
# Download reviews.txt and labels.txt from here: https://github.com/udacity/deep-learning/tree/master/sentiment-network

def pretty_print_review_and_label(i):
   print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# # Capturing Word Correlation in Input Data

# %%
import numpy as np

onehots = {}
onehots['cat'] = np.array([1,0,0,0])
onehots['the'] = np.array([0,1,0,0])
onehots['dog'] = np.array([0,0,1,0])
onehots['sat'] = np.array([0,0,0,1])

sentence = ['the','cat','sat']
x = onehots[sentence[0]] + \
    onehots[sentence[1]] + \
    onehots[sentence[2]]

print("Sent Encoding:" + str(x))
# Out:
# Sent Encoding:[1 1 0 1]

# %% [markdown]
# # Predicting Movie Reviews

# %%
import sys

f = open('reviews.txt')
raw_reviews = f.readlines()
f.close()

f = open('labels.txt')
raw_labels = f.readlines()
f.close()

tokens = list(map(lambda x:set(x.split(" ")),raw_reviews))

vocab = set()
for sent in tokens:
    for word in sent:
        if(len(word)>0):
            vocab.add(word)
vocab = list(vocab)

word2index = {}
for i,word in enumerate(vocab):
    word2index[word]=i

input_dataset = list()
for sent in tokens:
    sent_indices = list()
    for word in sent:
        try:
            sent_indices.append(word2index[word])
        except:
            ""
    input_dataset.append(list(set(sent_indices)))

target_dataset = list()
for label in raw_labels:
    if label == 'positive\n':
        target_dataset.append(1)
    else:
        target_dataset.append(0)

# %%
import numpy as np
np.random.seed(1)

def sigmoid(x):
    return 1/(1 + np.exp(-x))

alpha, iterations = (0.01, 2)
hidden_size = 100

weights_0_1 = 0.2*np.random.random((len(vocab),hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size,1)) - 0.1

correct,total = (0,0)
for iter in range(iterations):
    
    # train on first 24,000
    for i in range(len(input_dataset)-1000):

        x,y = (input_dataset[i],target_dataset[i])
        layer_1 = sigmoid(np.sum(weights_0_1[x],axis=0)) #embed + sigmoid
        layer_2 = sigmoid(np.dot(layer_1,weights_1_2)) # linear + softmax

        layer_2_delta = layer_2 - y # compare pred with truth
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) #backprop

        weights_0_1[x] -= layer_1_delta * alpha
        weights_1_2 -= np.outer(layer_1,layer_2_delta) * alpha

        if(np.abs(layer_2_delta) < 0.5):
            correct += 1
        total += 1
        
        if (i == 0) and (iter == 0):
            print(f'layer_1: \n' + \
                  f'  type                  {type(layer_1)}\n' + \
                  f'  weights_0_1[x].shape  {weights_0_1[x].shape}\n' + \
                  f'  layer_1_delta.shape   {layer_1_delta.shape}')
            print(f'layer_2: \n' + \
                  f'  shape                 {layer_2.shape}\n' + \
                  f'  weights_1_2.shape     {weights_1_2.shape}\n' + \
                  f'  layer_2_delta.shape   {layer_2_delta.shape}')
            
        if(i % 10 == 9):
            progress = str(i/float(len(input_dataset)))
            sys.stdout.write('\rIter:'+str(iter)\
                             +' Progress:'+progress[2:4]\
                             +'.'+progress[4:6]\
                             +'% Training Accuracy:'\
                             + str(correct/float(total)) + '%')
    print()
correct,total = (0,0)
for i in range(len(input_dataset)-1000,len(input_dataset)):

    x = input_dataset[i]
    y = target_dataset[i]

    layer_1 = sigmoid(np.sum(weights_0_1[x],axis=0))
    layer_2 = sigmoid(np.dot(layer_1,weights_1_2))
    
    if(np.abs(layer_2 - y) < 0.5):
        correct += 1
    total += 1
print("Test Accuracy:" + str(correct / float(total)))
# Out:
# <class 'numpy.ndarray'>
# layer_1:
#   type                  <class 'numpy.ndarray'>
#   weights_0_1[x].shape  (93, 100)
#   layer_1_delta.shape   (100,)
# layer_2:
#   shape                 (1,)
#   weights_1_2.shape     (100, 1)
#   layer_2_delta.shape   (1,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.03% Training Accuracy:0.0%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.07% Training Accuracy:0.15%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.11% Training Accuracy:0.1%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.15% Training Accuracy:0.15%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.19% Training Accuracy:0.26%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.23% Training Accuracy:0.23333333333333334%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.27% Training Accuracy:0.2%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.31% Training Accuracy:0.225%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.35% Training Accuracy:0.2222222222222222%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.39% Training Accuracy:0.23%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.43% Training Accuracy:0.23636363636363636%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.47% Training Accuracy:0.23333333333333334%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.51% Training Accuracy:0.2230769230769231%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.55% Training Accuracy:0.22857142857142856%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.59% Training Accuracy:0.23333333333333334%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.63% Training Accuracy:0.25%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.67% Training Accuracy:0.25882352941176473%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.71% Training Accuracy:0.26666666666666666%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.75% Training Accuracy:0.26842105263157895%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.79% Training Accuracy:0.28%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.83% Training Accuracy:0.3%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.87% Training Accuracy:0.3090909090909091%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.91% Training Accuracy:0.30869565217391304%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.95% Training Accuracy:0.32083333333333336%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:00.99% Training Accuracy:0.336%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.03% Training Accuracy:0.3384615384615385%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.07% Training Accuracy:0.337037037037037%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.11% Training Accuracy:0.33214285714285713%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.15% Training Accuracy:0.3413793103448276%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.19% Training Accuracy:0.3433333333333333%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.23% Training Accuracy:0.34838709677419355%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.27% Training Accuracy:0.35625%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.31% Training Accuracy:0.36363636363636365%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.35% Training Accuracy:0.36470588235294116%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.39% Training Accuracy:0.3742857142857143%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.43% Training Accuracy:0.37777777777777777%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.47% Training Accuracy:0.372972972972973%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.51% Training Accuracy:0.3736842105263158%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.55% Training Accuracy:0.382051282051282%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.59% Training Accuracy:0.3825%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.63% Training Accuracy:0.3902439024390244%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.67% Training Accuracy:0.3904761904761905%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.71% Training Accuracy:0.39069767441860465%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.75% Training Accuracy:0.3886363636363636%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.79% Training Accuracy:0.3888888888888889%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.83% Training Accuracy:0.3869565217391304%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.87% Training Accuracy:0.3893617021276596%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.91% Training Accuracy:0.39375%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.95% Training Accuracy:0.39183673469387753%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:01.99% Training Accuracy:0.392%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.03% Training Accuracy:0.3941176470588235%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.07% Training Accuracy:0.39615384615384613%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.11% Training Accuracy:0.39811320754716983%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.15% Training Accuracy:0.40185185185185185%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.19% Training Accuracy:0.4%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.23% Training Accuracy:0.3982142857142857%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.27% Training Accuracy:0.39824561403508774%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.31% Training Accuracy:0.4017241379310345%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.35% Training Accuracy:0.4033898305084746%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.39% Training Accuracy:0.41%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.43% Training Accuracy:0.41147540983606556%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.47% Training Accuracy:0.4129032258064516%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.51% Training Accuracy:0.4174603174603175%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.55% Training Accuracy:0.4171875%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.59% Training Accuracy:0.42%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.63% Training Accuracy:0.42424242424242425%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.67% Training Accuracy:0.42686567164179107%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.71% Training Accuracy:0.4308823529411765%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.75% Training Accuracy:0.43333333333333335%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.79% Training Accuracy:0.4328571428571429%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.83% Training Accuracy:0.43380281690140843%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.87% Training Accuracy:0.43333333333333335%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.91% Training Accuracy:0.43561643835616437%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.95% Training Accuracy:0.43783783783783786%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:02.99% Training Accuracy:0.43866666666666665%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.03% Training Accuracy:0.4368421052631579%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.07% Training Accuracy:0.44025974025974024%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.11% Training Accuracy:0.43974358974358974%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.15% Training Accuracy:0.4417721518987342%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.19% Training Accuracy:0.44375%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.23% Training Accuracy:0.4444444444444444%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.27% Training Accuracy:0.45%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.31% Training Accuracy:0.4530120481927711%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.35% Training Accuracy:0.4583333333333333%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.39% Training Accuracy:0.46%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.43% Training Accuracy:0.4569767441860465%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.47% Training Accuracy:0.45977011494252873%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.51% Training Accuracy:0.4602272727272727%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.55% Training Accuracy:0.46179775280898877%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.59% Training Accuracy:0.46555555555555556%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.63% Training Accuracy:0.46813186813186813%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.67% Training Accuracy:0.47282608695652173%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.71% Training Accuracy:0.47634408602150535%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.75% Training Accuracy:0.4787234042553192%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.79% Training Accuracy:0.4789473684210526%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.83% Training Accuracy:0.48020833333333335%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.87% Training Accuracy:0.48350515463917526%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.91% Training Accuracy:0.48673469387755103%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.95% Training Accuracy:0.4919191919191919%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:03.99% Training Accuracy:0.496%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.03% Training Accuracy:0.500990099009901%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.07% Training Accuracy:0.503921568627451%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.11% Training Accuracy:0.5067961165048543%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.15% Training Accuracy:0.5096153846153846%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.19% Training Accuracy:0.5114285714285715%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.23% Training Accuracy:0.5141509433962265%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.27% Training Accuracy:0.516822429906542%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.31% Training Accuracy:0.5166666666666667%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.35% Training Accuracy:0.5192660550458715%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.39% Training Accuracy:0.5209090909090909%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.43% Training Accuracy:0.5234234234234234%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.47% Training Accuracy:0.5258928571428572%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.51% Training Accuracy:0.5283185840707965%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.55% Training Accuracy:0.5307017543859649%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.59% Training Accuracy:0.5347826086956522%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.63% Training Accuracy:0.5362068965517242%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.67% Training Accuracy:0.5393162393162393%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.71% Training Accuracy:0.5406779661016949%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.75% Training Accuracy:0.5394957983193277%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.79% Training Accuracy:0.5375%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.83% Training Accuracy:0.5355371900826447%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.87% Training Accuracy:0.5360655737704918%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.91% Training Accuracy:0.5373983739837398%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.95% Training Accuracy:0.5387096774193548%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:04.99% Training Accuracy:0.5376%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.03% Training Accuracy:0.5404761904761904%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.07% Training Accuracy:0.5417322834645669%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.11% Training Accuracy:0.5421875%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.15% Training Accuracy:0.5449612403100775%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.19% Training Accuracy:0.546923076923077%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.23% Training Accuracy:0.5488549618320611%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.27% Training Accuracy:0.5507575757575758%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.31% Training Accuracy:0.5526315789473685%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.35% Training Accuracy:0.5529850746268656%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.39% Training Accuracy:0.5548148148148148%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.43% Training Accuracy:0.5566176470588236%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.47% Training Accuracy:0.5583941605839416%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.51% Training Accuracy:0.5572463768115942%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.55% Training Accuracy:0.5597122302158274%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.59% Training Accuracy:0.5607142857142857%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.63% Training Accuracy:0.5638297872340425%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.67% Training Accuracy:0.5626760563380282%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.71% Training Accuracy:0.5629370629370629%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.75% Training Accuracy:0.5638888888888889%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.79% Training Accuracy:0.5655172413793104%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.83% Training Accuracy:0.5664383561643835%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.87% Training Accuracy:0.5666666666666667%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.91% Training Accuracy:0.5668918918918919%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.95% Training Accuracy:0.5671140939597316%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:05.99% Training Accuracy:0.57%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.03% Training Accuracy:0.5728476821192053%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.07% Training Accuracy:0.575%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.11% Training Accuracy:0.5771241830065359%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.15% Training Accuracy:0.577922077922078%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.19% Training Accuracy:0.5774193548387097%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.23% Training Accuracy:0.5788461538461539%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.27% Training Accuracy:0.5802547770700637%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.31% Training Accuracy:0.5816455696202532%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.35% Training Accuracy:0.5836477987421383%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:06.39% Training Accuracy:0.58375%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# ...
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.51% Training Accuracy:0.8120281509916827%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.55% Training Accuracy:0.8119565217391305%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.59% Training Accuracy:0.8120127795527157%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.63% Training Accuracy:0.8120051085568327%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.67% Training Accuracy:0.8120612635609444%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.71% Training Accuracy:0.8120535714285714%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.75% Training Accuracy:0.8121096239643085%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.79% Training Accuracy:0.8121019108280255%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.83% Training Accuracy:0.8120942075111394%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.87% Training Accuracy:0.8122137404580153%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.91% Training Accuracy:0.812269548633185%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.95% Training Accuracy:0.8121982210927573%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:62.99% Training Accuracy:0.8121269841269841%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.03% Training Accuracy:0.8121827411167513%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.07% Training Accuracy:0.8123018389346861%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.11% Training Accuracy:0.8122306717363752%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.15% Training Accuracy:0.8122229259024699%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.19% Training Accuracy:0.8123417721518987%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.23% Training Accuracy:0.8123972169512966%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.27% Training Accuracy:0.8125158027812895%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.31% Training Accuracy:0.8125078963992419%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.35% Training Accuracy:0.8124368686868687%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.39% Training Accuracy:0.812429022082019%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.43% Training Accuracy:0.8123581336696091%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.47% Training Accuracy:0.8124133585381222%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.51% Training Accuracy:0.8124685138539043%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.55% Training Accuracy:0.812586532410321%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.59% Training Accuracy:0.8125157232704403%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.63% Training Accuracy:0.8125707102451288%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.67% Training Accuracy:0.8126256281407035%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.71% Training Accuracy:0.8126804770872568%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.75% Training Accuracy:0.8126097867001255%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.79% Training Accuracy:0.8124137931034483%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.83% Training Accuracy:0.812468671679198%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.87% Training Accuracy:0.8121477770820288%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.91% Training Accuracy:0.8120150187734668%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.95% Training Accuracy:0.8120700437773608%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:63.99% Training Accuracy:0.8120625%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.03% Training Accuracy:0.8121174266083697%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.07% Training Accuracy:0.8121722846441948%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.11% Training Accuracy:0.8122270742358079%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.15% Training Accuracy:0.812219451371571%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.19% Training Accuracy:0.8123364485981308%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.23% Training Accuracy:0.8123287671232877%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.27% Training Accuracy:0.8121966397013067%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.31% Training Accuracy:0.8122512437810945%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.35% Training Accuracy:0.8122436295835923%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.39% Training Accuracy:0.8122360248447205%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.43% Training Accuracy:0.8122905027932961%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.47% Training Accuracy:0.8123449131513648%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.51% Training Accuracy:0.8123372597644142%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.55% Training Accuracy:0.812453531598513%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.59% Training Accuracy:0.8125077399380805%<class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Iter:0 Progress:64.63% Training Accuracy:0.8126237623762376%

# %%
tokens[0]
# Out:
# {'',
#  '\n',
#  '.',
#  'a',
#  'about',
#  'adults',
#  'age',
#  'all',
#  'and',
#  'as',
#  'at',
#  'believe',
#  'bromwell',
#  'burn',
#  'can',
#  'cartoon',
#  'classic',
#  'closer',
#  'comedy',
#  'down',
#  'episode',
#  'expect',
#  'far',
#  'fetched',
#  'financially',
#  'here',
#  'high',
#  'i',
#  'immediately',
#  'in',
#  'insightful',
#  'inspector',
#  'is',
#  'isn',
#  'it',
#  'knew',
#  'lead',
#  'life',
#  'line',
#  'm',
#  'many',
#  'me',
#  'much',
#  'my',
#  'of',
#  'one',
#  'other',
#  'pathetic',
#  'pettiness',
#  'pity',
#  'pomp',
#  'profession',
#  'programs',
#  'ran',
#  'reality',
#  'recalled',
#  'remind',
#  'repeatedly',
#  'right',
#  's',
#  'sack',
#  'same',
#  'satire',
#  'saw',
#  'school',
#  'schools',
#  'scramble',
#  'see',
#  'situation',
#  'some',
#  'student',
#  'students',
#  'such',
#  'survive',
#  't',
#  'teachers',
#  'teaching',
#  'than',
#  'that',
#  'the',
#  'their',
#  'think',
#  'through',
#  'time',
#  'to',
#  'tried',
#  'welcome',
#  'what',
#  'when',
#  'which',
#  'who',
#  'whole',
#  'years',
#  'your'}

# %% [markdown]
# # Comparing Word Embeddings

# %%
from collections import Counter
import math 

def similar(target='beautiful'):
    target_index = word2index[target]
    scores = Counter()
    for word,index in word2index.items():
        raw_difference = weights_0_1[index] - (weights_0_1[target_index])
        squared_difference = raw_difference * raw_difference
        scores[word] = -math.sqrt(sum(squared_difference))

    return scores.most_common(10)

# %%
print(similar('beautiful'))
# Out:
# [('beautiful', -0.0), ('heart', -0.7461901055360456), ('captures', -0.7767713774499612), ('impact', -0.7851006592549541), ('unexpected', -0.8024296074764704), ('bit', -0.8041029062033365), ('touching', -0.8041105203290175), ('true', -0.8092335336931215), ('worth', -0.8095649927927353), ('strong', -0.8095814455120289)]

# %%
print(similar('terrible'))
# Out:
# [('terrible', -0.0), ('boring', -0.7591663900380615), ('lame', -0.7732283645546325), ('horrible', -0.788081854105546), ('disappointing', -0.7893120726668719), ('avoid', -0.7939105009456955), ('badly', -0.8054784389155504), ('annoying', -0.8067172753479477), ('dull', -0.8072650189634973), ('mess', -0.8139036459320503)]

# %% [markdown]
# # Filling in the Blank

# %%
import sys,random,math
from collections import Counter
import numpy as np

np.random.seed(1)
random.seed(1)
f = open('reviews.txt')
raw_reviews = f.readlines()
f.close()

tokens = list(map(lambda x:(x.split(" ")),raw_reviews))
wordcnt = Counter()
for sent in tokens:
    for word in sent:
        wordcnt[word] -= 1
vocab = list(set(map(lambda x:x[0],wordcnt.most_common())))

word2index = {}
for i,word in enumerate(vocab):
    word2index[word]=i

concatenated = list()
input_dataset = list()
for sent in tokens:
    sent_indices = list()
    for word in sent:
        try:
            sent_indices.append(word2index[word])
            concatenated.append(word2index[word])
        except:
            ""
    input_dataset.append(sent_indices)
concatenated = np.array(concatenated)
random.shuffle(input_dataset)

# %%
alpha, iterations = (0.05, 2)
hidden_size,window,negative = (50,2,5)

weights_0_1 = (np.random.rand(len(vocab),hidden_size) - 0.5) * 0.2
weights_1_2 = np.random.rand(len(vocab),hidden_size)*0

layer_2_target = np.zeros(negative+1)
layer_2_target[0] = 1

def similar(target='beautiful'):
  target_index = word2index[target]

  scores = Counter()
  for word,index in word2index.items():
    raw_difference = weights_0_1[index] - (weights_0_1[target_index])
    squared_difference = raw_difference * raw_difference
    scores[word] = -math.sqrt(sum(squared_difference))
  return scores.most_common(10)

def sigmoid(x):
    return 1/(1 + np.exp(-x))

for rev_i,review in enumerate(input_dataset * iterations):
  for target_i in range(len(review)):
        
    # since it's really expensive to predict every vocabulary
    # we're only going to predict a random subset
    target_samples = [review[target_i]]+list(concatenated\
    [(np.random.rand(negative)*len(concatenated)).astype('int').tolist()])

    left_context = review[max(0,target_i-window):target_i]
    right_context = review[target_i+1:min(len(review),target_i+window)]

    layer_1 = np.mean(weights_0_1[left_context+right_context],axis=0)
    layer_2 = sigmoid(layer_1.dot(weights_1_2[target_samples].T))
    layer_2_delta = layer_2 - layer_2_target
    layer_1_delta = layer_2_delta.dot(weights_1_2[target_samples])

    weights_0_1[left_context+right_context] -= layer_1_delta * alpha
    weights_1_2[target_samples] -= np.outer(layer_2_delta,layer_1)*alpha

  if(rev_i % 250 == 0):
    sys.stdout.write('\rProgress:'+str(rev_i/float(len(input_dataset)
        *iterations)) + "   " + str(similar('terrible')))
  sys.stdout.write('\rProgress:'+str(rev_i/float(len(input_dataset)
        *iterations)))
print(similar('terrible'))
# Out:
# Progress:0.99998[('terrible', -0.0), ('horrible', -3.488841411481131), ('bad', -4.0636425093941595), ('brilliant', -4.211247495138625), ('pathetic', -4.304645745396163), ('fantastic', -4.341998952418319), ('fabulous', -4.356925869405997), ('phenomenal', -4.361301237074382), ('marvelous', -4.3856957968039145), ('spectacular', -4.413156799233535)]

# %% [markdown]
# # King - Man + Woman ~= Queen

# %%
def analogy(positive=['terrible','good'],negative=['bad']):
    
    norms = np.sum(weights_0_1 * weights_0_1,axis=1)
    norms.resize(norms.shape[0],1)
    
    normed_weights = weights_0_1 * norms
    
    query_vect = np.zeros(len(weights_0_1[0]))
    for word in positive:
        query_vect += normed_weights[word2index[word]]
    for word in negative:
        query_vect -= normed_weights[word2index[word]]
    
    scores = Counter()
    for word,index in word2index.items():
        raw_difference = weights_0_1[index] - query_vect
        squared_difference = raw_difference * raw_difference
        scores[word] = -math.sqrt(sum(squared_difference))
        
    return scores.most_common(10)[1:]

# %%
analogy(['terrible','good'],['bad'])
# Out:
# [('terrific', -210.46593317724228),
#  ('perfect', -210.52652806032205),
#  ('worth', -210.53162266358495),
#  ('good', -210.55072184482773),
#  ('terrible', -210.58429046605724),
#  ('decent', -210.87945442008805),
#  ('superb', -211.01143515971094),
#  ('great', -211.1327058081335),
#  ('worthy', -211.13577238103477)]

# %%
analogy(['elizabeth','he'],['she'])
# Out:
# [('simon', -193.82490698964878),
#  ('obsessed', -193.91805919583555),
#  ('stanwyck', -194.22311983847902),
#  ('sandler', -194.22846640800597),
#  ('branagh', -194.24551334589853),
#  ('daniel', -194.24631020485714),
#  ('peter', -194.29908544092078),
#  ('tony', -194.31388897167716),
#  ('aged', -194.35115773165094)]
