# %% [markdown]
# [Datacamp Course – Intermediate SQL](https://app.datacamp.com/learn/courses/29303?variant=ai_native)

# %% [markdown]
# ---

# %%
# %load_ext sql
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# SELECT 1 AS test;
# Out:
#  * sqlite://
# Done.
# [(1,)]

# %% [markdown]
# ---
