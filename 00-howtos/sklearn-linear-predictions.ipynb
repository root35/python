# %% [markdown]
# [Linear Regression in Pictures](http://adit.io/posts/2016-02-20-Linear-Regression-in-Pictures.html): predicting values (e.g. price of a house)
# [Logistic Regression in Pictures](http://adit.io/posts/2016-03-13-Logistic-Regression.html): predicting classes (e.g. type of fruit)
